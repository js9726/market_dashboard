# %% [markdown]
# # Using Natural Language Processing on News articles to find the sentiment of the news realted to Gold

# %% [markdown]
# **Data 602 : Intro to Data Analysis and Machine Learning**
#
# **Professor:** Dr. Antonio Diana

# %% [markdown]
# **Team:**
#
#
# *   Hariom Vyas
# *   Krutal Patel
# *   Viral Jani
# *   Durga Siva Sai Verma Rudraraju

# %% [markdown]
# Here we are using multipple techniques to find news related to gold on internet. We are using packages like NewsCatcher to go through websites like Guardian and finding if they have any top news related to gold on them to stay updated on latest trend.
#
# We are using Google news to find recent top news on gold.
#
# After that we are using BeautifulSoup and request to go through diffrent articles and doing sentiment analysis on them. We are doing sentiment analysis using multiple ways.
#
#
# *   Textblob
# *   Pattern
#
# We are generating word cloud for all the news for visualizing unstructured text data and getting insights on trends and patterns.

# %% [markdown]
# ## Installing required packages and dependancies

# %%
# !pip install pattern
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pattern in /usr/local/lib/python3.8/dist-packages (3.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pattern) (4.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from pattern) (2.28.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pattern) (1.7.3)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.8/dist-packages (from pattern) (5.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pattern) (1.21.6)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from pattern) (0.16.0)
# Requirement already satisfied: backports.csv in /usr/local/lib/python3.8/dist-packages (from pattern) (1.0.7)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.8/dist-packages (from pattern) (0.8.11)
# Requirement already satisfied: mysqlclient in /usr/local/lib/python3.8/dist-packages (from pattern) (2.1.1)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.8/dist-packages (from pattern) (20221105)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from pattern) (4.11.1)
# Requirement already satisfied: cherrypy in /usr/local/lib/python3.8/dist-packages (from pattern) (18.8.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from pattern) (3.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.8/dist-packages (from beautifulsoup4->pattern) (2.3.2.post1)
# Requirement already satisfied: jaraco.collections in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern) (3.8.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern) (9.0.0)
# Requirement already satisfied: portend>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern) (3.1.0)
# Requirement already satisfied: cheroot>=8.2.1 in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern) (9.0.0)
# Requirement already satisfied: zc.lockfile in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern) (2.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.8/dist-packages (from cheroot>=8.2.1->cherrypy->pattern) (3.5.2)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from cheroot>=8.2.1->cherrypy->pattern) (1.15.0)
# Requirement already satisfied: tempora>=1.8 in /usr/local/lib/python3.8/dist-packages (from portend>=2.1.1->cherrypy->pattern) (5.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern) (2022.6)
# Requirement already satisfied: jaraco.text in /usr/local/lib/python3.8/dist-packages (from jaraco.collections->cherrypy->pattern) (3.11.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.8/dist-packages (from jaraco.collections->cherrypy->pattern) (3.2.3)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (4.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (5.10.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (2.1.0)
# Requirement already satisfied: autocommand in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (2.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->jaraco.text->jaraco.collections->cherrypy->pattern) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (2022.6.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->pattern) (1.2.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six->pattern) (38.0.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six->pattern) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->pattern) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->pattern) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->pattern) (1.24.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from zc.lockfile->cherrypy->pattern) (57.4.0)

# %%
# !pip install pygooglenews
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pygooglenews in /usr/local/lib/python3.8/dist-packages (0.1.2)
# Requirement already satisfied: dateparser<0.8.0,>=0.7.6 in /usr/local/lib/python3.8/dist-packages (from pygooglenews) (0.7.6)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.8/dist-packages (from pygooglenews) (4.11.1)
# Requirement already satisfied: feedparser<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pygooglenews) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.8/dist-packages (from pygooglenews) (2.28.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.8/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->pygooglenews) (2.3.2.post1)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (1.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2.8.2)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.6.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from dateparser<0.8.0,>=0.7.6->pygooglenews) (2022.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->pygooglenews) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil->dateparser<0.8.0,>=0.7.6->pygooglenews) (1.15.0)

# %%
# !pip install newscatcher
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: newscatcher in /usr/local/lib/python3.8/dist-packages (0.2.0)
# Requirement already satisfied: tldextract<3.0.0,>=2.2.2 in /usr/local/lib/python3.8/dist-packages (from newscatcher) (2.2.3)
# Requirement already satisfied: feedparser<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from newscatcher) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.8/dist-packages (from newscatcher) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.23.0->newscatcher) (1.24.3)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.8/dist-packages (from tldextract<3.0.0,>=2.2.2->newscatcher) (1.5.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from requests-file>=1.4->tldextract<3.0.0,>=2.2.2->newscatcher) (1.15.0)

# %%
# Imprting required libraries

import requests
import nltk
from bs4 import BeautifulSoup
import urllib.request,sys,time
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import random
from wordcloud import WordCloud
import os
import spacy
nlp = spacy.load('en_core_web_sm')
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('stopwords')
from textblob import TextBlob
from pattern.en import sentiment
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## News from NewsCatcher

# %%
from newscatcher import Newscatcher, describe_url

newcatcher_news = []

mm = Newscatcher(website = 'https://www.theguardian.com/us')

for index, headline in enumerate(mm.get_headlines()):
   newcatcher_news.append(headline)
  
print(newcatcher_news)
# Out:
# ['Twitter moderators turn to automation amid a reported surge in hate speech', 'FTX chief Sam Bankman-Fried says he ‘screwed up’ but rejects fraud claim', 'Musk says brain chip to begin human trials soon – and plans to get one himself', 'Password app LastPass hit by cybersecurity breach but says data remains safe', 'NBN losses to reach $25bn by 2040, report finds', 'FTX billionaire Sam Bankman-Fried funneled dark money to Republicans', 'Macron says he had ‘clear and honest’ discussion with Musk on Twitter policy', '#ClimateScam: denialism claims flooding Twitter have scientists worried', 'Elon Musk’s satellites to be part of UK trial to get internet to remote areas', 'EU raises prospect of big fine or ban if Twitter fails to follow new legislation', 'Pegasus spyware inquiry targeted by disinformation campaign, say experts', 'Amazon has delivered £3,500-worth of the same cookbook', 'Mobiles are ‘potential goldmines’ for hostile states, MPs warned', 'Australian companies don’t value keeping our data safe because they have little to lose. Our laws need to change that | George Newhouse and Duncan Fine', 'Medibank: how hackers got your private health data', 'Medibank data theft: hackers release records they claim are related to mental health and alcohol issues', 'Medibank hacker says ransom demand was US$10m as purported abortion health records posted', 'Ransomware group starts publishing Medibank data as company warns customers to be vigilant for scammers', '‘I still wince when I think about it’: 10 text messages – and the stories behind them', 'Could we have one app for everything? We ask an expert', 'Cracking apps: are crimefighters going too far to bring down cartels?', 'Best podcasts of the week: How to die on screen, according to the stars of Halloween to Stranger Things', 'The death of Twitter has dragged on too long. Please, Elon, put us out of our misery | Jack Vening', 'Crypto will survive the FTX collapse – but more scandals will follow | Kenneth Rogoff', 'Why were so many smart people so dumb about FTX? Did they seriously just like Sam Bankman-Fried’s ‘vibe’?', 'Chaos unleashed: Elon Musk’s wild ride at helm of Twitter could bring it down', 'From Tron to Jumanji: the greatest ever movies about video games', 'Marvel’s Midnight Suns review – superheroes, strategy and Gen Z banter', 'Pushing Buttons: There’s a place for narrative in games, but I’m done worshipping the story gods', 'The best retro video game consoles for 2022', 'I didn’t get my son’s favourite video game – but it got me | Dominik Diamond', '‘No one had seen anything like it’: how video game Pong changed the world', 'Sam Bankman-Fried’s fall hasn’t killed off ‘effective altruism’ | Brief letters', 'The gods of Silicon Valley are falling to earth. So are their warped visions for society | Moya Lothian-McLean', 'Power-hungry robots, space colonization, cyborgs: inside the bizarre world of ‘longtermism’', 'Major investor calls on Google owner to ‘aggressively’ cut staff and pay', 'Apple TV 4K 2022 review: cheaper but still premium streaming box', 'Microsoft Surface Laptop 5 review: slick operation but dated design', 'Access All Areas review – brave family’s quest to change attitudes to disability', 'iPhone 14 Plus review: Apple’s big-screen battery champ', 'The Secret Genius of Modern Life review – irresistibly contagious TV', 'Zombiegate review – a Halloween night dive into online toxicity', 'Apple Watch Ultra review: the super-charged smartwatch', 'iPad Pro M2 review: tremendous hardware, but software needs work', 'Alexa, how did Amazon’s wrong call on voice assistants tee up a $10bn loss? | John Naughton', '‘I wondered which world this woman was about to shoot out into’: Chris Maliwat’s best phone picture', 'What will happen next for Black Twitter?', 'What are dabloons?: Tiktok’s new imaginary economy explained', '‘My friends call me the BlackBerry queen!’ Meet the people clinging on to old tech – from faxes to VCRs', 'TechScape: How do you slice a billion-d ...

# %%
cloud_words = ""

for val in newcatcher_news:
  val = str(val)
  tokens = val.split()
  for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
  cloud_words += " ".join(tokens)+" "

# %%
# Plotting Word Cloud

plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(cloud_words)
plt.imshow(wordcloud)
plt.title('NEWS ARTICLE (100 words)')
plt.axis('off')
plt.show()

# %% [markdown]
# ## News from Google News

# %%
from pygooglenews import GoogleNews

google_news = []

gn = GoogleNews()
s = gn.search('gold')

for entry in s["entries"]:
    google_news.append(entry["title"])

print(google_news)
# Out:
# ['Gold retreats from near 4-month peak on positive U.S. jobs data - CNBC', 'Sentiment shows gold price has the momentum to move solidly above $1800 - Kitco NEWS', 'Gold and silver off to the races, or is this another false start - Kitco NEWS', 'Gold price powers to 3.5-mo. High, more upside likely - Kitco NEWS', '3 of the best times to invest in gold - CBS News', 'London gold body creates database of Russian bullion bars - Reuters', 'Gold flat as dollar rises - CNBC', 'Gold has a path to $2000 and silver to $25 in the second half of 2023 - Bank of America - Kitco NEWS', 'A new way of trading and spending gold is catching on in the Mountain West - Wyoming Public Media', 'Gold Chains Look Sexy on All Genders, All Body Types - The New York Times', "Technical outlook: Gold price may cross ₹54,000 mark in Dec. Here's why | Mint - Mint", 'Falling head grades put pressure on gold mining industry - report - Kitco NEWS', 'Gold/Silver: Christmas came early | Kitco News - Kitco NEWS', 'Gold Price To Hit New Record By End Of 2027, Expert Forecasts - Forbes', 'Gold slips as dollar regains, Fed officials back higher rates - Reuters', "Bitcoin's Crash Could Bring New Life to Gold - Barron's", 'Gold near three-month high on latest Russia jitters - CNBC', 'Gold set for best week in over 2 years on Fed slowdown hopes - CNBC', "Now is the time to build a small position in gold even if prices can move lower - DeCarley Trading's Carley Garner - Kitco NEWS", 'Gold slides as dollar marches ahead - CNBC', 'How much is gold worth? - CBS News', 'HSBC will have to share custody with JPMorgan of $52 bln in gold bars - Reuters', 'Where is gold headed next week? Vote now! - Kitco NEWS', 'Drake’s Nike NOCTA Hot Step Air Terra Appears In White, Gold, And Icy Soles - Sneaker News', 'Closing Prices for Crude Oil, Gold and Other Commodities (Dec. 2) - The Epoch Times', "Gold Mid-Tiers' Q3'22 Fundamentals (NYSEARCA:GDXJ) - Seeking Alpha", 'Venezuela’s gold: 10 ways to address illicit financial flows from the mineral trade - Brookings Institution', 'Gold price up by Rs 550, trading at Rs 53,730; silver rises by Rs 700 - Business Standard', "Treasure hunter's gold discovery leads to torturous legal odyssey - Detroit News", 'Holiday Gift Guide 2022: Statement Gold Jewelry For Women - Forbes', 'Gold prices slip - VnExpress International', 'From junkyard to green gold, Brightwood-Lincoln Elementary school commemorates award with plaque - MassLive.com', "Where Did Missouri's Jesse James Hide His Gold? New Clues Found - 100.9 The Eagle", "It's going to be a 'lively December' for gold price - Pepperstone - Kitco NEWS", 'Delaware State Police Issue Gold Alert for Missing Lewes Man - Delaware State Police - State of Delaware - Delaware.gov', 'Gold Breaks Three Records on Day One of Gompei Invitational - Brandeis Athletics', 'Luxury: All that glitters is not gold (really!) - Hindustan Times', 'Gold Price Forecast: XAU/USD eyes a consolidate phase as 200DMA caps – Credit Suisse - FXStreet', 'As ITVX banks on World Cup gold, is channel too late to streaming party? - The Guardian', 'U.S. Fed Move: Gold Aside, What Will Other Precious Metals Do? - Investing.com', 'West Chester University women go for gold in Seattle tonight - Brotherly Game', 'White & Gold Christmas Trees For 2022 Are On-Trend, Experts Say - Elite Daily', 'Gold soars as U.S. jobs data raises Fed slowdown hopes - CNBC', 'Gold prices up by record Tk7,698 per bhori - Dhaka Tribune', 'The Fed pivot will be good for gold in 2023, says Bank of America - Morningstar', 'Northwest Estate Buyers roadshow comes to town; instantly sell your gold, jewelry, coins and more - St George News', "Supporting the 'Gold Standard' for Wildlife-Conscious Cannabis Cultivation - Humboldt State Now", 'Garnet & Gold Scholar Society welcomes 35 new members - Florida State News', 'Track Opens Indoor Season With Blue and Gold Invitational - Notre Dame Athletics', 'Cardano Founder Indicates "Gold Standard of Digital Age," and It Is Not ADA - ...

# %%
cloud_words = ""

for val in google_news:
  val = str(val)
  tokens = val.split()
  for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
  cloud_words += " ".join(tokens)+" "

# %%
# Plotting Word Cloud

plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(cloud_words)
plt.imshow(wordcloud)
plt.title('NEWS ARTICLE (100 words)')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Part 1: Web Scraping the Articles

# %%
# Getting news articles using get from request packagge

r=requests.get('https://www.kitco.com/news/2022-12-02/Sentiment-shows-gold-price-has-the-momentum-to-move-solidly-above-1-800.html')

# %%
#Setting encoding of the HTML page
r.encoding = 'utf-8'

# %%
# Extracting the HTML from the request object
html = r.text

# %%
# Printing the first 500 characters in html
print(html[:500])
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" itemscope itemtype="http://schema.org/Article"><!-- InstanceBegin template="/Templates/media_article_v2.dwt" codeOutsideHTMLIsLocked="false" -->
# 	<head>
#
#
# 				<title>Sentiment shows gold price has the momentum to move solidly above $1,800 | Kitco News</title>
# 				<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
# 		<meta name="viewport" content="width=device-width, initial-scale=1">
#
# 		   <!-- p

# %%
# Creating a BeautifulSoup object from the HTML
soup = BeautifulSoup(html)
# Getting the text out of the soup
text = soup.get_text()

# %%
#total length
len(text)
# Out:
# 17245

# %%
#having a look at the text
print(text[100:1100])
# Out:
# Make Kitco Your Homepage
#
#
#
#
# Login
#
#
# Sign Up
#
# Refresh Page
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
# Buy/Sell Gold &
# 							Silver Bullion Coins and Bars
#
#
# Online Store
#
#
#
# Buy Gold & Silver
#
#
# Great Deals
#
#
# Gift Ideas
#
#
# Cool and Collectible
#
#
# Gold
#
#
# Gold Coins
#
#
# Gold Bars
#
#
# Silver
#
#
# Silver Coins
#
#
# Silver Rounds
#
#
# Silver Bars
#
#
# Platinum
#
#
# Platinum Coins
#
#
# Platinum Bars
#
#
# Palladium
#
#
# Rhodium
#
#
# Bullion Mints
#
#
# Kitco Pool
#
#
# VaultChain™
#
# GOLD
# SILVER
#
#
#
# Sell Gold & Silver
#
#
# Coins and Bars
#
#
# Rhodium Products
#
#
# Kitco Pool
#
#
# Refining and Scrap
#
# VaultChain™ Gold
# VaultChain™ Silver
#
# Storage Programs
#
# Kitco AllocatedStorage Program
#
# IRA/RSP
# VaultChain™
#
# Refining Services
#
# Jeweler Resources
# Reference Tables
# Refining
#                                                     and Scrap
#
# Institutional and  Wholesale Services
#
#
# Customer Service
#
# Contact Us
# Shipping and Insurance
# Payments andCancellations
# Business Hours
#
# Retail Store Lo

# %%
# Text Cleaning

clean_text= text.replace("n", " ")
clean_text= clean_text.replace("/", " ")       
clean_text= ''.join([c for c in clean_text if c != "'"])

# %%
clean_text
# Out:
# '\n\nSe time t shows gold price has the mome tum to move solidly above $1,800 | Kitco News\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMake Kitco Your Homepage\n\n\n\n\nLogi \n\n\nSig  Up\n\nRefresh Page\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\n\n\n\nBuy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio  Coi s a d Bars\r\n\t\t\t\t\t\n\nO li e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat Deals\n\n\nGift Ideas\n\n\nCool a d Collectible\n\n\nGold\n\n\nGold Coi s\n\n\nGold Bars\n\n\nSilver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\n\nSilver Bars\n\n\nPlati um\n\n\nPlati um Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nRhodium\n\n\nBullio  Mi ts\n\n\nKitco Pool\n\n\nVaultChai ™\n\nGOLD\nSILVER\n\n\n\nSell Gold & Silver\n\n\nCoi s a d Bars\n\n\nRhodium Products\n\n\nKitco Pool\n\n\nRefi i g a d Scrap\n\nVaultChai ™ Gold\nVaultChai ™ Silver\n\nStorage Programs\n\nKitco AllocatedStorage Program\n\nIRA RSP\nVaultChai ™\n\nRefi i g Services\n\nJeweler Resources\nRefere ce Tables\nRefi i g\r\n                                                    a d Scrap\n\nI stitutio al a d  Wholesale Services\n\n\nCustomer Service\n\nCo tact Us\nShippi g a d I sura ce\nPayme ts a dCa cellatio s\nBusi ess Hours\n\nRetail Store Locatio \n\nFeedback\n\nFAQs\n\n\nMy\r\n                                            Kitco Accou t\n\nOpe \r\n                                                    a  Accou t\nActivate\r\n                                                    O li e Profile\nCheck\r\n                                                    Tra sactio  Status\nReset\r\n                                                    Password\n\nPromotio al EmailsSig  Up\n\n\n\n\n\n\n\n\nAll Metal Quotes\n\nAll Metal\r\n\t\t\t\t\t\t\t\tQuotes\n\n\n\nLo do \r\n\t\t\t\t\t\t\t\t\t\t\tFix Prices\nSha ghai Gold Fix\nPrecious Metals Prices Today\n\nGold Price Today\nSilver Price Today\nPlati um Price Today\nPalladium Price Today\n\nPrecious Metals Quotes by Curre cy\nMetals\r\n\t\t\t\t\t\t\t\t\t\t\tFutures\nKitco Silver\nBase Metals\nStrategic Metals\n\nText Quotes\nFree Web Quote Ba  ers\n\n\n\n\n  \n\n\n\nCharts & Data\n\nCharts &\r\n\t\t\t\t\t\t\t\tData\n\n\n\nLive Charts\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\nTech ical Charts\n\nGold\nSilver\nPlati um\nPalladium\n\nFree Charts o  yourWeb\r\n\t\t\t\t\t\t\t\t\t\t\tSite\n\n\nHistorical\r\n\t\t\t\t\t\t\t\t\t\t\tCharts & Data\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\nLo do  Fix Prices\n\nMarket Fu dame tals\n\nGold\nSilver\n\nFree Web Quote Ba  ers\n\n\nI teractive\r\n\t\t\t\t\t\t\t\t\t\t\tCharts\n\n\nPrecious Metals\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\n\nBase Metals\n\nAlumi um\nCopper\nNickel\nLead\nZi c\n\nCurre cy Excha ge Rates\n\nAUD\nBRL\nCAD\nCHF\nCNY\nEUR\nGBP\n\n\nHKD\nINR\nJPY\nMXN\nRUB\nZAR\n\n\n\n\n\n  \n\n\n\nCrypto\n\nCrypto Market\n\n\n\nCrypto News\nMarkets\n\nBitcoi \nEthereum\nBi a ce Coi \nXRP\nSola a\nCarda o\nDogecoi \nAvala che\nPolkadot\nShiba I u\nPolygo \n\n\n\n\nChai li k\nU iswap\nNear Protocol\nAxie I fi ity\nThe Sa dbox\nDece trala d\nCosmos\nFa tom\nTheta Network\n\nNewsletters Sig up\nRSS\nAdvertise With Us\n\n\n\n\n\n\nFollow us o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMarkets\n\nMarkets\n\n\n\n\nMarkets\r\n\t\t\t\t\t\t\t\t\t\t\tOverview\n\nDow\n\nNasdaq\n\nS&P\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t500\nNYSE\n\nGold\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tVIX\nMost Active Stocks\n\n\n\nMi i g\n\nGold\n\nSilver\n\nIro \n\nBase\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tMetals\nNo -Ferrous\n\n\n\n\nFutures\n\nMetals\n\nE ergies\n\nGrai s\n\nI dices\n\nSofts\n\nMeats\n\nRates\n\nCurre cies\n\n\n\n\n\n\nForex Major\r\n\t\t\t\t\t\t\t\t\t\t\tRates\n\nCurre cy Co verter\nCurre cy Cross Rates\n\n\n\n\nCryptocurre cies\n\nBitcoi \nEthereum\nLitecoi \nMo ero\nRipple\nDash\nZcash\nPeercoi \nNamecoi \n\n\n\nStocks Gai ers& Losers\n\n\n\n\nKitco Gold\r\n\t\t\t\t\t\t ...

# %%
sentence=[]
tokens = nlp(clean_text)
for sent in tokens.sents:
    sentence.append((sent.text.strip()))

# %%
sentence
# Out:
# ['Se time t shows gold price has the mome tum to move solidly above $1,800 | Kitco News\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMake Kitco Your Homepage\n\n\n\n\nLogi \n\n\nSig  Up\n\nRefresh Page\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome',
#  'Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio  Coi s a d Bars\r\n\t\t\t\t\t\n\nO li',
#  'e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat Deals\n\n\nGift Ideas\n\n\nCool a d Collectible\n\n\nGold\n\n\nGold Coi s\n\n\nGold Bars',
#  'Silver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\n\nSilver Bars\n\n\nPlati um\n\n\nPlati um',
#  'Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nRhodium\n\n\nBullio  Mi ts\n\n\nKitco Pool\n\n\nVaultChai ™\n\nGOLD\nSILVER\n\n\n\nSell Gold & Silver\n\n\nCoi s a d Bars\n\n\nRhodium Products\n\n\nKitco Pool\n\n\nRefi',
#  'i g a d Scrap\n\nVaultChai ™ Gold\nVaultChai ™ Silver\n\nStorage Programs\n\nKitco AllocatedStorage Program\n\nIRA RSP\nVaultChai ™',
#  'Refi i g Services\n\nJeweler Resources\nRefere ce Tables',
#  'Refi i g\r\n                                                    a d Scrap\n\nI stitutio al a d  Wholesale Services\n\n\nCustomer Service\n\nCo tact Us\nShippi g',
#  'a d I sura ce\nPayme ts a dCa cellatio s\nBusi ess Hours\n\nRetail Store Locatio \n\nFeedback\n\nFAQs\n\n\nMy\r\n                                            Kitco Accou t\n\nOpe \r\n                                                    a  Accou t\nActivate\r\n                                                    O li e Profile\nCheck\r\n                                                    Tra sactio  Status\nReset\r\n                                                    Password\n\nPromotio al EmailsSig  Up\n\n\n\n\n\n\n\n\nAll Metal Quotes\n\nAll Metal\r\n\t\t\t\t\t\t\t\tQuotes\n\n\n\nLo do \r\n\t\t\t\t\t\t\t\t\t\t\tFix Prices\nSha ghai',
#  'Gold Fix\nPrecious Metals Prices Today\n\nGold Price',
#  'Today\nSilver Price Today\nPlati um Price Today\nPalladium Price Today\n\nPrecious Metals Quotes by Curre cy\nMetals\r\n\t\t\t\t\t\t\t\t\t\t\tFutures\nKitco Silver\nBase Metals\nStrategic Metals\n\nText Quotes\nFree Web',
#  'Quote Ba  ers',
#  'Charts & Data\n\nCharts &\r\n\t\t\t\t\t\t\t\tData\n\n\n\nLive Charts\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\nTech ical Charts\n\nGold\nSilver\nPlati um\nPalladium\n\nFree Charts o  yourWeb\r\n\t\t\t\t\t\t\t\t\t\t\tSite\n\n\nHistorical\r\n\t\t\t\t\t\t\t\t\t\t\tCharts & Data\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\nLo do  Fix Prices\n\nMarket Fu',
#  'dame tals\n\nGold\nSilver\n\nFree Web',
#  'Quote Ba  ers\n\n\nI teractive\r\n\t\t\t\t\t\t\t\t\t\t\tCharts\n\n\nPrecious Metals\n\nGold\nSilver\nPlati um',
#  'Palladium\nRhodium\n\n\n\nBase Metals\n\nAlumi um\nCopper\nNickel\nLead\nZi c\n\nCurre cy Excha ge Rates\n\nAUD\nBRL\nCAD\nCHF\nCNY\nEUR\nGBP\n\n\nHKD\nINR\nJPY\nMXN\nRUB\nZAR\n\n\n\n\n\n  \n\n\n\nCrypto\n\nCrypto Market\n\n\n\nCrypto News\nMarkets\n\nBitcoi \nEthereum\nBi',
#  'a ce Coi \nXRP\nSola a\nCarda o\nDogecoi \nAvala',
#  'che\nPolkadot',
#  'Shiba',
#  'I u\nPolygo \n\n\n\n\nChai li k\nU iswap\nNear Protocol',
#  'Axie I fi',
#  'ity\nThe Sa dbox\nDece trala',
#  'd\nCosmos\nFa tom\nTheta Network\n\nNewsletters Sig up\nRSS\nAdvertise With Us\n\n\n\n\n\n\nFollow us o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMarkets\n\nMarkets\n\n\n\n\nMarkets\r\n\t\t\t\t\t\t\t\t\t\t\tOverview\n\nDow\n\nNasdaq\n\nS&P\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t500\nNYSE\n\nGold\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tVIX\nMost Active Stocks\n\n\n\nMi',
#  'i g\n\nGold\n\nSilver\n\nIro \n\nBase\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tMetals\nNo -Ferrous\n\n\n\n\nFutures\n\nMetals\n\nE ergies\n\nGrai s\n\nI dices\n\nSofts\n\nMeats\n\nRates\n\nCurre cies\n\n\n\n\n\n\nForex Major\r\n\t\t\t\t\t\t\t\t\t\t\tRates\n\nCurre cy Co verter\nCurre cy Cross Rates\n\n\n\n\nCryptocurre cies',
#  'Bitcoi \nEthereum\nLitecoi \nMo ero\nRipple\nDash\nZcash\nPeercoi \nNamecoi \n\n\n\nStocks Gai ers& Losers\n\n\n\n\nKitco Gold\r\n\t\t\t\t\t\t\t\t\t\t\tI dex\n\n\nMetals\n\n\nSearch Stocks',
#  'News\n\nNews\n\n\n\nLatest News\n\nGold News\nAM-PM Rou dup\nEco omic News\n\nExclusive Features\n\nGold Survey\nGold Outlook\nKitco Focus\n\n\nVideo News\nOff',
#  'The Wire\nMore News\n\n\n\n\nCrypto News\nMi i g News\nSearch News\n\n\nNewsletters Sig up\nAbout Kitco NEWS\nRSS Feed\nAdvertise With Us\n\n\n\n\n\n\n\nFollow us',
#  'o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\nComme taries\n\nComme taries\n\n\n\nA alysis',
#  'Jim Wyckoff\nA alytical Charts\nWhere Are the Stops\nForex Charts\n\n\nComme tators Cor er\nCo tributed Comme taries\nCPM Group\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\nKitco Select',
#  'Jo atha  Da Silva\nGary Wag',
#  'er\nTodd Bubba Horwitz\nFra k E. Holmes\nPhillip Streible\nMickey Fulp\nDavid Erfle',
#  'Mi i',
#  'g',
#  'Mi',
#  'i g',
#  'Mi i g News\nVideo News\nPodcast\nLatest Press  Releases\nMi',
#  'i g by Sector\n\nGold\nSilver\nIro \nBase-Metals\nNo -Ferrous\n\n\n\nMetals Futures\nMi',
#  'i g Stock I dices',
#  'XAU\nNYSE Arca Gold BUGS\nJSE Gold\nTSX Gold\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\n\n\n\n\nFollow us o :\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\nGold Forum\n\nGold Forum\n\n\n\nGold Forum\n\nLogi \n\nFAQ\nTodays\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tPosts\nMembership\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tRules\n\n\n\n\n\n  \n\n\n\nMobile Apps\n\nMobile Apps\n\n\n\nKitco Applicatio s\n\n\nOur applicatio s are powerful, easy-to-use a d available o  all devices.',
#  'Gold Live!',
#  'iOS\n\nGold Live!',
#  'A droid\n\nGold Live!',
#  'A droid Widget\nGold Live!',
#  'Desktop\nWi dows\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tTaskbar\n\n\n\nMarket Alerts\n\n\nFree tool to help with golda d silver buyi g a d\r\n\t\t\t\t\t\t\t\t\t\t\t\tselli',
#  'g decisio s\n\nMy Alerts Accou t\nOpe  a  Accou t\n\nScrapIt!',
#  'Real-time gold scrap value calculator for professio als\r\n\t\t\t\t\t\t\t\t\t\t\t\n\n\niPho e •\r\n\t\t\t\t\t\t\t\t\t\t\tA droid •\r\n\t\t\t\t\t\t\t\t\t\t\tWeb\n\n\nMetaly x\n\n\n\nCalculate precious metaldime',
#  'sio s, weights a d\r\n\t\t\t\t\t\t\t\t\t\t\t\tpurity\n\n\niPho e •\r\n\t\t\t\t\t\t\t\t\t\t\tA droid\n\n\n\n\n\n\n  \n\n\n\nJeweler  Resources\n\nJeweler\r\n\t\t\t\t\t\t\t\tResources\n\n\n\nRefi i g',
#  'Services\nRefere ce Tables\n\nMelti',
#  'g Poi ts\nDWT Oz Gram Co versio',
#  'Gauge',
#  'I ch mm\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tCo versio \nWeight Compariso \n\n\nMetaly x\n\n\nCalculate precious metal dime',
#  'sio s, weights a d purity\r\n\t\t\t\t\t\t\t\t\t\t\t\n\n\nScrapIt!\n\n\nReal-time gold scrap value calculator for professio als\r\n\t\t\t\t\t\t\t\t\t\t\t\n\n\n\n\n\n\n  \n\n\n\nAbout\n\nAbout\n\n\n\nAbout Kitco\n\nWho We\r\n\t\t\t\t\t\t\t\t\t\t\t\t\tAre\nWhat We Do\nCareers',
#  'Media Ce ter\nCo tact Us\nFeedback\n\nAdvertise With Us\nSitemap\n\n\n\n\n  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n Favorites:\n\n\n\n\n\n\n\n\n\n\n\n\nEDIT\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nO li e',
#  'Store\n\n\n\nBuy from Kitco\n\n\nGreat Deals!',
#  'Cool a d Collectible\nBu dle Products\nGold Products\nSilver Products\nPlati um Products\nPalladium Products\nRhodium Products\nAccessories\nKitco Pool\n\n\n\n\nVaultChai  ™\n\n\nGOLD\nSILVER\n\n\n\n\nStorage Programs',
#  'Kitco Allocated Storage Program\nIRA RSP\nRoyal Ca adia  Mi t Prestige Accou t\nVaultChai ™\n\n\n\n\nSell to Kitco\n\n\nCoi s a d Bars\nRhodium Products\nKitco Pool\nRefi',
#  'i g a d Scrap\nVaultChai',
#  '™ Gold\nVaultChai ™ Silver\n\n\n\n\nRefi i g Services\n\n\nJeweler Resources',
#  'Refere ce Tables',
#  'Refi i g a d Scrap\n\n\n\nI stitutio al a d Wholesale Services\n\nCustomer Service\n\n\nCo tact Us\nShippi g',
#  'a d I sura ce\nPayme ts a dCa cellatio s\nBusi ess Hours\nRetail Store Locatio \nFeedback\nFAQs',
#  'My Kitco Accou t\n\n\nOpe  a  Accou t\nActivate',
#  'O li e Profile\nCheck Tra sactio  Status\nReset Password\n\n\n\n\nPromotio al Emails Sig  Up\n\n\n\n\n\n\n\n\n\n\nAll Metal Quotes\n\n\nLo do  Fix Prices\nPrecious Metals Quotes by',
#  'Curre cy\nMetals Futures\nKitco Silver\nBase Metals\nStrategic Metals\n\nText Quotes\nFree Web',
#  'Quote Ba  ers\n\n\n\n  \n\n\n\nCharts & Data\n\n\n\nLive Charts\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\n\n\n\n\nTech ical Charts\n\n\nGold\nSilver',
#  'Plati um\nPalladium\n\n\n\nFree Charts o  your Web Site\n\nHistorical Charts & Data\n\n\nGold\nSilver\nPlati um\nPalladium\nRhodium\nLo do  Fix Prices\n\n\n\n\nMarket Fu dame tals\n\n\nGold\nSilver\n\n\n\nFree Web Quote Ba  ers\n\nI',
#  'teractive Charts\n\n\nPrecious Metals\nGold\nSilver\nPlati um\nPalladium\nRhodium\nBase Metals\nAlumi um\nCopper\nNickel\nLead\nZi c\n\n\nCurre cy Excha ge Rates\n\n\nAUD\nHKD\nBRL\nINR\nCAD\nJPY\nCHF\nMXN\nCNY\nRUB\nEUR\nZAR\nGBP\n\n\n\n\n\n\n  \n\n\n\nCrypto Market\n\n\nCrypto News\n\nMarkets\n\n\nBitcoi \nEthereum\nBi a ce Coi \nXRP\nSola a\nCarda o\nDogecoi \nAvala',
#  'che\nPolkadot',
#  'Shiba',
#  'I u\nPolygo \nChai li k\nU iswap\nNear Protocol',
#  'Axie I fi',
#  'ity\nThe Sa dbox\nDece trala',
#  'd\nCosmos\nFa tom\nTheta Network\n\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\n  \n\n\n\nMarkets\n\n\n\nMarket Overview\n\n\nDow\nNasdaq\nS&P 500\nNYSE\nGold VIX\nMost Active Stocks\n\n\n\n\nForex Major Rates\n\n\nCurre cy Co verter\nCurre cy Cross Rates\n\n\n\nKitco Gold',
#  'I dex',
#  'Mi',
#  'i g\n\n\nGold\nSilver\nIro \nBase Metals\nNo -Ferrous\n\n\n\nBitcoi \nMetals\n\nFutures\n\n\nMetals\nE ergies\nGrai s\nI dices\nSofts\nMeats\nRates\nCurre cies\n\n\n\nStocks Gai ers & Losers',
#  'Search Stocks\n\n\n\n  \n\n\n\nNews\n\n\n\nLatest News\n\n\nGold News\nAM-PM Rou dup\nEco omic News\n\n\n\n\nExclusive Features\n\n\nGold Survey\nGold Outlook\nKitco Focus\n\n\n\nVideo  ews\nOff The Wire\nMore News\nCrypto News',
#  'Mi i g News\nSearch News\nNewsletters Sig up\nAbout Kitco NEWS\nRSS Feed\nAdvertise With Us\n\n\n\n  \n\n\n\nComme taries\n\n\n\nA alysis\n\n\nJim Wyckoff\nA alytical Charts\nWhere Are the Stops\nForex Charts\n\n\n\nComme tators Cor er\nCo tributed Comme taries\nCPM Group\nNewsletters Sig up\nRSS Feed\nAdvertise With Us',
#  'Kitco Select\n\n\nJo atha  Da Silva\nGary Wag',
#  'er\nTodd Bubba Horwitz\nFra k E. Holmes\nPhillip Streible\nMickey Fulp\nDavid Erfle',
#  'Mi i g\n\n\nMi',
#  'i g News\nVideo News\nPodcast\nLatest Press Releases',
#  'Mi',
#  'i g by Sector\n\n\nGold\nSilver\nIro \nBase-Metals',
#  'No -Ferrous\n\n\n\n\nMi i g Stock I dices',
#  'XAU\nNYSE Arca Gold BUGS\nJSE Gold\nTSX Gold\n\n\n\nNewsletters Sig up\nRSS Feed\nAdvertise With Us\n\n\n\n  \n\n\n\nGold Forum\n\n\n\nGold Forum\n\n\nLogi \nFAQ\nTodays Posts\nMembership Rules\n\n\n\n\n\n\n  \n\n\n\nMobile Apps\n\n\n\nKcast Gold Live\n\n\nFree live gold price, charts,  ews\niPho e\niPad\nA droid\nA droid Widget\nWi dows Pho e 7\nBlackberry\nBlackberry Playbook\nWi dows Taskbar\nDesktop for Mac, PC or Wi dows\n\n\n\n\nMarket Alerts\n\n\nFree tool for maki g buyi g a d selli',
#  'g decisio s\nMy Alerts Accou t\nOpe  a  Accou t\n\n\n\n\nScrapIt!',
#  'Real-time gold scrap value calculator for professio als\niPho e\nA droid\nWeb\n\n\n\n\nMetaly x\n\n\nCalculate precious metal dime sio s, weights a d purity\niPho e\nBlackberry\nA droid\n\n\n\n\n\n\n  \n\n\n\nJeweler Resources\n\n\nRefi',
#  'i g Services\n\nRefere ce Tables\n\n\nMelti',
#  'g Poi',
#  'ts\nDWT Oz Gram Co versio \nGauge',
#  'I ch mm',
#  'Co versio \nWeight Compariso \n\n\n\n\nMetaly',
#  'x\n\n\nScrapIt!\n\n\n\n\n\n\n\n\n\n\nAbout\n\n\n\nAbout Kitco\n\n\nWho We Are\nWhat We Do\nCareers\nMedia Ce ter\nCo tact Us\nFeedback\n\n\n\nAdvertise With Us\nSitemap',
#  'You are i',
#  'Home >',
#  'News >',
#  'Exclusive Features >',
#  'Gold Survey\n\n\n\n\n\n\n\n\n\n\nGold Survey\n\n\n\n\nSe time t shows gold price has the mome tum to move solidly above $1,800\n\n\n\n\n\n\n\n\nNeils Christe se \n\n\n\n\n\n\nFriday December 02, 2022 13:48\n\n\n\n\n\n\n\nKitco News\n\nShare this article:',
#  'Editors Note: With so much market volatility, stay o  top of daily  ews!',
#  'Get caught up i  mi utes with our speedy summary of todays must-read  ews a d expert opi io s. Sig  up here!',
#  '(Kitco News) -',
#  'A stro g start to  December as prices e d the week above $1,800 a d  ear their highest level i   more tha  three mo ths is creati g sig ifica t bullish se time t',
#  'i  the  marketplace; however, the questio  remai s if se time t will be e ough to bri g  i vestors off the sideli es.',
#  'The latest Kitco News  Weekly Gold Survey shows that Wall Street a alysts a d Mai  Street retail',
#  'i vestors are sig ifica tly bullish o  gold i  the  ear term as the market sees  solid tech ical bullish mome tum.',
#  'The rally i  gold started  Wed esday whe  Federal Reserve Chair Jerome Powell said that it could be  appropriate for the U.S. ce tral',
#  'ba k',
#  'to slow its pace of tighte i',
#  'g i   December.',
#  'At the same time,  a alysts have also said that growi g recessio  fears are also providi g a fresh  safe-have  boost to gold.',
#  'Coli  Cieszy ski, chief  market strategist at SIA Wealth Ma ageme t, said that he remai s bullish o   gold eve  if risi g',
#  'i terest rates co ti ue to support the U.S. dollar.',
#  '"I vestors are  starti g to realize that gold is still a  importa t defe sive asset," he  said.',
#  '"It co ti ues to play its role as a store of value."',
#  'Adam Butto , head of  curre cy strategy at Forexlive.com, said that gold is also be efiti g from  positive seaso al factors as dema d picks up ahead of the holidays.',
#  '"The seaso al tre d  of gold-buyi g i  December kicked i  from the first day of the mo th.',
#  'With the  Fed tilti g a d the U.S. dollar slidi g, the stars are alig ed for gold,"  he said.',
#  'This week, 18 Wall  Street a alysts participated i  the Kitco News Gold Survey.',
#  'Amo g the  participa ts, 12 a alysts, or 67%, were bullish o  gold i  the  ear term a d  six a alysts, or 33%, were bearish for  ext week.',
#  'There were  o  eutral votes  i  this weeks survey.',
#  'Mea while, 1,018 votes  were cast i  a  o li e Mai  Street poll.',
#  'Of these, 715 respo de ts, or 70%,  looked for gold to rise  ext week.',
#  'A other 188, or 18%, said it would be lower,  while 115 voters, or 11%, were  eutral i  the  ear term.',
#  'Wall Street\n Bullish    \n Bearish    \n Neutral   \n\nVS\n\nMai  Street\n Bullish    \n Bearish    \n Neutral   \n\n\nThe solidly optimistic  outlook comes as gold prices look to e d the week with a 2% gai , with February  gold futures last tradi g at $1,809 a  ou ce.',
#  'Eve  a stro ger-tha -expected  November employme t report with stro g wage growth has  ot bee  e ough to  dampe  golds  ew mome tum.',
#  'Friday, the Bureau of  Labor Statistics said 263,000 jobs were created i  November; eco omists  expected job gai s of 200,000.',
#  'At the same time, wages i creased 5.1% for the  year, well above expectatio s. \nDari  Newsom, se ior  market a alyst at Barchart, said that  ext week could be exciti g for the  precious metal as the curre t rally could be see  as a tech ical blowoff top;  however, he added mome tum is clearly o  the bullish side.',
#  '"Its markets like  gold that lead to dri ki g problems for tech ical a alysts," he said.',
#  '"Give  weekly stochastics have  ot clearly moved above the overbought  level of 80%, Feb gold looks to have time a d space to move higher  ext week.',
#  'However, a d heres where thi gs get fu , its target area is betwee  $1,807.20  (with this weeks high already $1,818.70) a d $1,861.20."',
#  'However,  ot all  a alysts are bullish o  gold, at least i  the  ear-term.',
#  'Adria  Day, preside t  of Adria  Day Asset Ma ageme t, said that while he remai s a lo g-term gold  bull, he does see gold prices dippi g  ext week.',
#  '',
#  'GLD positio',
#  'i g itself for future growth with seco d custodia  for its gold\n\n\n"We will likely see  some follow-through to the decli e o  the latest U.S. jobs report, which showed  more  ew jobs tha  estimated, as well as a  atural correctio  to a sharp weekly  rally," he said.',
#  '"But after that, a recovery, as more market  participa ts come to appreciate that the Federal Reserve (a d other ce tral  ba ks, particularly the ECB a d BoE) simply will be u able to achieve their  i flatio  targets without provoki g a serious recessio .',
#  'Sig s of a  impe di g  recessio  are gatheri g." \nMarc Cha dler, ma agi g  director of Ba  ockbur  Global Forex, said that he is bearish o  gold  ext week  as markets are too optimistic o  Powells supposed dovish sta ce.',
#  'He added that risi g  wages i  Novembers employme t report show that the Federal Reserve still has  to deal with a growi',
#  'g i flatio  problem.',
#  '"Gold the  looks  likely to reject the false break above the 200-day movi g average.',
#  'I look for  $1765 a d maybe $1750 before the FOMC meeti',
#  'g i  the middle of the mo th,"  he said.',
#  'By Neils Christe se \n\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t \t\t\t\tFor Kitco News\n\nFollow  eils_C\n\n\n\n christe se @kitco.com\n\n\n\n\nwww.kitco.com',
#  'Disclaimer:',
#  'The views expressed i  this article are those of the author a d may  ot reflect those of Kitco Metals I c.',
#  'The author has made every effort to e sure accuracy of i formatio  provided; however,  either Kitco Metals I c.  or the author ca  guara tee such accuracy.',
#  'This article is strictly for i formatio al purposes o ly.',
#  'It is  ot a solicitatio  to make a y excha',
#  'ge i  commodities, securities or other fi a cial i strume ts.',
#  'Kitco Metals I c. a d the author of this article do  ot accept culpability for losses a d  or damages arisi g from the use of this publicatio .',
#  '',
#  'ew\n\n\n\n\n\nTodays Crypto Markets\n\n\n\n\n\nBitcoi \n\n\n\n\n\n\n\n\n\n\n\nEthereum\n\n\n\n\n\n\n\n\n\n\n\nXRP\n\n\n\n\n\n\n\n\n\nMore crypto markets a d  ews...\n\n\n\n\n\n\n Latest Articles\n\n\nNews\n\nVideo News\n\nComme taries\n\n\n\n\n\n\n\nCopper processi',
#  'g compa y gets backi g from BMW\n\nDec  3, 2022 11:53AM\n\n\n\n\n\n\n\nFalli g head grades put pressure',
#  'o  gold',
#  'mi i',
#  'g i dustry - report',
#  'Dec  2, 2022 07:39PM\n\n\n\n\n\n\n\nGold a d silver off to the races, or is this a other false start\n\nDec  2, 2022 05:28PM\n\n\n\n\n\n\n\nSolid performa ces from gold & silver a d a jobs report above expectatio s\n\nDec  2, 2022 05:23PM\n\n\n\n\n\n\n\nBitcoi  holds above $17K as U.S. jobs data comes i  stro ger tha  expected\n\nDec  2, 2022 05:17PM\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSolid performa ces from gold & silver a d a jobs report above expectatio s\n\nDec  2, 2022 05:22PM\n\n\n\n\n\n\n\nGold Silver: Christmas came early\n\nDec  2, 2022 04:29PM\n\n\n\n\n\n\n\nWhat just happe ed to gold a d silver prices...',
#  'A d what did t!',
#  'Dec  2, 2022 02:35PM\n\n\n\n\n\n\n\nDips i  precious metals prices may co ti ue to be shallow\n\nDec  2, 2022 12:46PM\n\n\n\n\n\n\n\nFriday Charts for Gold, Silver a d Plati um a d Palladium, December 2',
#  'Dec  2, 2022 10:54AM\n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n Precious Metal Charts\n\n\nGold\nSilver\nPlati um\nPalladium\n\n\n\n24h\n30D\n60D\n6M\n1Y\n\n\xa0\nI teractive Chart\n\n\n\n\n\n Follow Kitco News\n\nTweets by KitcoNewsNOW\n\n\n\n\n\n\n\n\n3460379\n2\n  www.kitco',
#  'et.com \n\n\n\n\n\n\nKitco\nHome\nAll Metal Quotes\nCharts & Data\nMarkets\nNews\nComme taries',
#  'Mi i g\nCo  ect\nAbout Us\nKitco Media\nCareers\nCo tact Us\nAdvertise With Us\n\n\nTools\nKitco Gold',
#  'I dex\nI teractive Gold Chart\nBitcoi',
#  'i  USD\nCurre cy Co verter\nScrapIt!',
#  'Mobile Applicatio \nSite Map\nO li',
#  'e Store\n\n Be I formed of our\r\n\t\t\t\t\tspecial offers, alerts a d  ews.',
#  'sig  up\n\n\n\n We appreciate your\r\n\t\t\t\t\tfeedback.',
#  'Submit\r\n\t\t\t\t\t\n\n\n\n\nVisit Kitco\r\n\t\t\t\t\tMobile Apps\n\n\n\n\n\n\r\n\t\t\t\t\tHow ca  we help you?',
#  '1 877 775-4826\n\n\n\n\n\n\n\n\n\n\n\n\r\n\t\t\t\t\tDrop us a li e i fo@kitco.com',
#  'Website Terms of Use |\nTerms & Co ditio s\nPrivacy Policy']

# %%
# Printing length of sentences

print(len(sentence))
# Out:
# 171

# %%
# Looking at the random sentence to verify
print(sentence[2])
# Out:
# e Store
#
#
#
# Buy Gold & Silver
#
#
# Great Deals
#
#
# Gift Ideas
#
#
# Cool a d Collectible
#
#
# Gold
#
#
# Gold Coi s
#
#
# Gold Bars

# %% [markdown]
# ## Part 2: Sentiment Analysis with Textblob

# %%
textblob_sentiment=[]
for s in sentence:
    txt= TextBlob(s)
    a= txt.sentiment.polarity
    b= txt.sentiment.subjectivity
    textblob_sentiment.append([s,a,b])

# %%
df_textblob = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_textblob.head()
# Out:
#                                             Sentence  Polarity  Subjectivity
# 0  Se time t shows gold price has the mome tum to...  0.000000      0.100000
# 1  Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio...  0.000000      0.000000
# 2  e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat De...  0.216667      0.733333
# 3  Silver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\...  0.000000      0.000000
# 4  Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nR...  0.000000      0.000000

# %%
df_textblob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      171 non-null    object
#  1   Polarity      171 non-null    float64
#  2   Subjectivity  171 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.1+ KB

# %%
# Analyzing polarity using visuals

sns.displot(df_textblob["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Textblob)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Polarity (Textblob)')

# %% [markdown]
# Due to some reason around half the sentences have zero polarity. Maybe, its because of the dact they are neutral. A few sentences are highly positive and a few are negative.

# %%
# Analyzing subjectivity using visuals

sns.displot(df_textblob["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Textblob)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Subjectivity (Textblob)')

# %% [markdown]
# The values of subjectivity also very with few sentences being highly subjective and a majority of sentences being less subjective.

# %% [markdown]
# ## Part 3: Sentiment Analysis with Pattern

# %%
pattern_sentiment=[]
for s in sentence:
    res= sentiment(s)
    c= res[0]
    d= res[1]
    pattern_sentiment.append([s,c,d])

# %%
pattern_sentiment[1]
# Out:
# ['Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio  Coi s a d Bars\r\n\t\t\t\t\t\n\nO li',
#  0.0,
#  0.0]

# %%
df_pattern = pd.DataFrame(textblob_sentiment, columns =['Sentence', 'Polarity', 'Subjectivity'])

# %%
df_pattern.head()
# Out:
#                                             Sentence  Polarity  Subjectivity
# 0  Se time t shows gold price has the mome tum to...  0.000000      0.100000
# 1  Buy Sell Gold &\r\n\t\t\t\t\t\t\tSilver Bullio...  0.000000      0.000000
# 2  e Store\n\n\n\nBuy Gold & Silver\n\n\nGreat De...  0.216667      0.733333
# 3  Silver\n\n\nSilver Coi s\n\n\nSilver Rou ds\n\...  0.000000      0.000000
# 4  Coi s\n\n\nPlati um Bars\n\n\nPalladium\n\n\nR...  0.000000      0.000000

# %%
df_pattern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sentence      171 non-null    object
#  1   Polarity      171 non-null    float64
#  2   Subjectivity  171 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 4.1+ KB

# %%
# Plotting the scores

sns.displot(df_pattern["Polarity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Polarity (Pattern)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Polarity (Pattern)')

# %%
sns.displot(df_pattern["Subjectivity"], height= 5, aspect=1.8)
plt.xlabel("Sentence Subjectivity (Pattern)")
# Out:
# Text(0.5, 6.79999999999999, 'Sentence Subjectivity (Pattern)')

# %% [markdown]
# Similar data distribution can be seen.

# %% [markdown]
# ## Part 4: Word frequency and Word Cloud

# %%
# Creating the nltk tokenizer and Tokenizing text

tokens = nltk.tokenize.word_tokenize(clean_text)

# %%
len(tokens)
# Out:
# 3066

# %%
print(tokens[0:10])
# Out:
# ['Se', 'time', 't', 'shows', 'gold', 'price', 'has', 'the', 'mome', 'tum']

# %%
# Converting to lower cases for uniformality

words = []
# Looping through the tokens and make them lower case
for word in tokens:
    words.append(word.lower())

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
words_new = []
# Appending to words_new all words that are in words but not in stopwords
for word in words:
    if word not in stopwords:
        words_new.append(word)

# %%
len(words_new)
# Out:
# 2350

# %%
print(words_new[0:10])
# Out:
# ['se', 'time', 'shows', 'gold', 'price', 'mome', 'tum', 'move', 'solidly', '$']

# %%
# The frequency distribution of the words

freq_dist = nltk.FreqDist(words_new)

# %%
# Frequency Distribution Plot

plt.subplots(figsize=(16,10))
freq_dist.plot(20)

# %%
# Converting into string

res=' '.join([i for i in words_new if not i.isdigit()])

# %%
# Plotting Word Cloud

plt.subplots(figsize=(16,10))
wordcloud = WordCloud(
                          background_color='black',
                          max_words=100,
                          width=1400,
                          height=1200
                         ).generate(res)
plt.imshow(wordcloud)
plt.title('NEWS ARTICLE (100 words)')
plt.axis('off')
plt.show()
